# %%
import torch
import math

# %%
def trigger_vector_modification(self,gen_z,watermarking_dict):
    y = 0.5 * (1 + torch.erf(gen_z / math.sqrt(2))) 
    return y * math.sqrt(2 * math.pi)

# %%
batch_gpu = 1
z_dim = 10

# %%
gen_z = torch.randn((batch_gpu,z_dim),device='cuda')
print("Original gen_z:",gen_z)
# Out:
# Original gen_z: tensor([[-1.3941, -0.1169,  0.8677,  0.0995, -0.0244, -0.8756,  0.0692, -0.5708,
#           1.7235, -0.7343]], device='cuda:0')
